# %%
import pandas as pd

# %%
prison = pd.read_csv("https://OTexts.com/fpp3/extrafiles/prison_population.csv", parse_dates=True, index_col="Date")
prison
# Out:
#            State  Gender      Legal Indigenous  Count
# Date
# 2005-03-01   ACT  Female   Remanded       ATSI      0
# 2005-03-01   ACT  Female   Remanded   Non-ATSI      2
# 2005-03-01   ACT  Female  Sentenced       ATSI      0
# 2005-03-01   ACT  Female  Sentenced   Non-ATSI      5
# 2005-03-01   ACT    Male   Remanded       ATSI      7
# ...          ...     ...        ...        ...    ...
# 2016-12-01    WA  Female  Sentenced   Non-ATSI    220
# 2016-12-01    WA    Male   Remanded       ATSI    623
# 2016-12-01    WA    Male   Remanded   Non-ATSI    985
# 2016-12-01    WA    Male  Sentenced       ATSI   1463
# 2016-12-01    WA    Male  Sentenced   Non-ATSI   2625
#
# [3072 rows x 5 columns]

# %%
prison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3072 entries, 2005-03-01 to 2016-12-01
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State       3072 non-null   object
#  1   Gender      3072 non-null   object
#  2   Legal       3072 non-null   object
#  3   Indigenous  3072 non-null   object
#  4   Count       3072 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 144.0+ KB

# %%
implist = {
    'State': "first", 
    'Gender': "first",
    'Legal': "first",
    "Indigenous": "first", 
    'Count': "sum"
}
prison.resample('Q').apply(implist)
# Out:
#            State  Gender     Legal Indigenous  Count
# Date
# 2005-03-31   ACT  Female  Remanded       ATSI  24296
# 2005-06-30   ACT  Female  Remanded       ATSI  24643
# 2005-09-30   ACT  Female  Remanded       ATSI  24511
# 2005-12-31   ACT  Female  Remanded       ATSI  24393
# 2006-03-31   ACT  Female  Remanded       ATSI  24524
# 2006-06-30   ACT  Female  Remanded       ATSI  25017
# 2006-09-30   ACT  Female  Remanded       ATSI  25428
# 2006-12-31   ACT  Female  Remanded       ATSI  25913
# 2007-03-31   ACT  Female  Remanded       ATSI  25912
# 2007-06-30   ACT  Female  Remanded       ATSI  26517
# 2007-09-30   ACT  Female  Remanded       ATSI  26479
# 2007-12-31   ACT  Female  Remanded       ATSI  26547
# 2008-03-31   ACT  Female  Remanded       ATSI  26365
# 2008-06-30   ACT  Female  Remanded       ATSI  26733
# 2008-09-30   ACT  Female  Remanded       ATSI  27197
# 2008-12-31   ACT  Female  Remanded       ATSI  27428
# 2009-03-31   ACT  Female  Remanded       ATSI  27519
# ...

# %%
prison.shape
# Out:
# (3072, 5)
